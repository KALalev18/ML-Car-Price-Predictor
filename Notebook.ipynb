# %%
import pandas as pd

# %%
data = pd.read_csv("CarPrice_Assignment.csv")
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
data.head() # data.head(3) - for number
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
data.tail() # data.tail(3) - for number
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200   sedan        rwd          front      109.1  ...         141        mpfi
# 201   sedan        rwd          front      109.1  ...         141        mpfi
# 202   sedan        rwd          front      109.1  ...         173        mpfi
# 203   sedan        rwd          front      109.1  ...         145         idi
# 204   sedan        rwd          front      109.1  ...         141        mpfi
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
data.columns # no data types shown
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
data.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
data["CarName"].describe()
# Out:
# count               205
# unique              147
# top       toyota corona
# freq                  6
# Name: CarName, dtype: object

# %%
data["CarName"].describe().reset_index() # shows an excel data frame
# Out:
#     index        CarName
# 0   count            205
# 1  unique            147
# 2     top  toyota corona
# 3    freq              6

# %%
data["CarName"].describe().reset_index()["CarName"]
# Out:
# 0              205
# 1              147
# 2    toyota corona
# 3                6
# Name: CarName, dtype: object

# %%
izvadka = data["enginesize"].describe().reset_index()
izvadka["enginesize"] = round(izvadka["enginesize"], 2) # round a column info

# %%
izvadka
# Out:
#    index  enginesize
# 0  count      205.00
# 1   mean      126.91
# 2    std       41.64
# 3    min       61.00
# 4    25%       97.00
# 5    50%      120.00
# 6    75%      141.00
# 7    max      326.00

# %%
data.isna().sum().sum() # check if data is enabled (it's not)
# Out:
# 0

# %%
data.duplicated().sum() # check if data is duplicated (here not)
# Out:
# 0

# %%
data.dropna(inplace=True) # na values
data.drop_duplicates(inplace=True) # duplicated values

# %%
data.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
data.head().groupby("CarName")["price"].mean().sort_values(ascending=False).plot(kind="bar") 
plt.title("First five car names vs price")
plt.ylabel("Mean price")
plt.xlabel("Car name")
plt.show() # sort price of the top 5 cars + bar chart

# %%
data.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
data[["horsepower", "fuelsystem"]]
# Out:
#      horsepower fuelsystem
# 0           111       mpfi
# 1           111       mpfi
# 2           154       mpfi
# 3           102       mpfi
# 4           115       mpfi
# ..          ...        ...
# 200         114       mpfi
# 201         160       mpfi
# 202         134       mpfi
# 203         106        idi
# 204         114       mpfi
#
# [205 rows x 2 columns]

# %%
a = data[["carwidth", "carheight", "CarName", "wheelbase", "fuelsystem"]]
b = data[["price"]]

# %%
a
# Out:
#      carwidth  carheight                   CarName  wheelbase fuelsystem
# 0        64.1       48.8        alfa-romero giulia       88.6       mpfi
# 1        64.1       48.8       alfa-romero stelvio       88.6       mpfi
# 2        65.5       52.4  alfa-romero Quadrifoglio       94.5       mpfi
# 3        66.2       54.3               audi 100 ls       99.8       mpfi
# 4        66.4       54.3                audi 100ls       99.4       mpfi
# ..        ...        ...                       ...        ...        ...
# 200      68.9       55.5           volvo 145e (sw)      109.1       mpfi
# 201      68.8       55.5               volvo 144ea      109.1       mpfi
# 202      68.9       55.5               volvo 244dl      109.1       mpfi
# 203      68.9       55.5                 volvo 246      109.1        idi
# 204      68.9       55.5               volvo 264gl      109.1       mpfi
#
# [205 rows x 5 columns]

# %%
b
# Out:
#        price
# 0    13495.0
# 1    16500.0
# 2    16500.0
# 3    13950.0
# 4    17450.0
# ..       ...
# 200  16845.0
# 201  19045.0
# 202  21485.0
# 203  22470.0
# 204  22625.0
#
# [205 rows x 1 columns]

# %%
data.shape[0] * 0.8 # same stuff a a_train.shape first instance
# Out:
# 164.0

# %%
from sklearn.model_selection import train_test_split
a_train, a_test, b_train, b_test = train_test_split(a,b,test_size=0.2)

# %%
a_train.shape
# Out:
# (164, 5)

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.tree import DecisionTreeRegressor
param_grid = {
     "criterion": ["friedman_mse"],
     "splitter": ["best", "random"],
     "max_depth": [None, 10,20,30,40,50],
     "min_samples_split": [2,5,10],
     "min_samples_leaf": [1,5,10]
}

# %%
tree_model = DecisionTreeRegressor()

# %%
grid_tree = GridSearchCV(estimator = tree_model, param_grid = param_grid)

# %%
grid_tree.fit(a_train, b_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 grid_tree.fit(a_train, b_train)
#
# File c:\Users\Krist\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Krist\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:1018, in BaseSearchCV.fit(self, X, y, **params)
#    1012     results = self._format_results(
#    1013         all_candidate_params, n_splits, all_out, all_more_results
#    1014     )
# ...
